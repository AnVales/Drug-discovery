# %% [markdown]
# # Computational drug discovery: part 3
# ## Descriptor Calculation and Dataset Preparation

# %%
# Download PaDEL-Descriptor
# http://www.yapcwsoft.com/dd/padeldescriptor/
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://raw.githubusercontent.com/AnVales/Drug-discovery-part-1/main/padel.sh
# Out:
# --2021-09-03 11:24:17--  https://github.com/AnVales/Drug-discovery/blob/main/padel.zip
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘padel.zip’
#
# padel.zip               [ <=>                ] 126.78K  --.-KB/s    in 0.1s
#
# 2021-09-03 11:24:17 (1.10 MB/s) - ‘padel.zip’ saved [129819]
#
# --2021-09-03 11:24:17--  https://raw.githubusercontent.com/AnVales/Drug-discovery/main/padel.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231 [text/plain]
# Saving to: ‘padel.sh’
#
# padel.sh            100%[===================>]     231  --.-KB/s    in 0s
#
# 2021-09-03 11:24:18 (9.39 MB/s) - ‘padel.sh’ saved [231/231]

# %%
# Open zip
! unzip padel.zip
# Out:
# Archive:  padel.zip
# replace __MACOSX/._PaDEL-Descriptor? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Load bioactivity data: bioactivity_data_3class_pIC50.csv
# It contains the pIC50 values that we will be using for building a regression model
! wget -O genital_herpes_04_bioactivity_data_3class_pIC50.csv https://raw.githubusercontent.com/AnVales/Drug-discovery/main/genital_herpes_04_bioactivity_data_3class_pIC50.csv
# Out:
# --2021-09-03 11:30:20--  https://raw.githubusercontent.com/AnVales/Drug-discovery/main/genital_herpes_04_bioactivity_data_3class_pIC50.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34554 (34K) [text/plain]
# Saving to: ‘genital_herpes_04_bioactivity_data_3class_pIC50.csv’
#
# genital_herpes_04_b 100%[===================>]  33.74K  --.-KB/s    in 0.004s
#
# 2021-09-03 11:30:20 (8.22 MB/s) - ‘genital_herpes_04_bioactivity_data_3class_pIC50.csv’ saved [34554/34554]

# %%
# Import library
import pandas as pd

# %%
# Read bioactivity data
bioactivaty_data = pd.read_csv('genital_herpes_04_bioactivity_data_3class_pIC50.csv')
bioactivaty_data
# Out:
#      Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0             0       CHEMBL122071  ...           4.0  4.000000
# 1             1       CHEMBL124107  ...           4.0  4.167491
# 2             2       CHEMBL120853  ...           4.0  4.000000
# 3             3       CHEMBL122296  ...           4.0  5.187087
# 4             4       CHEMBL333734  ...           4.0  4.568636
# ..          ...                ...  ...           ...       ...
# 230         230       CHEMBL106921  ...           5.0  5.823909
# 231         231       CHEMBL107963  ...           7.0  5.619789
# 232         232       CHEMBL106641  ...           3.0  4.958607
# 233         233       CHEMBL108677  ...           7.0  7.214670
# 234         234       CHEMBL542448  ...           2.0  4.481486
#
# [235 rows x 9 columns]

# %%
# chembl_id & canonical smiles to smi
selection = ['canonical_smiles','molecule_chembl_id']
bioactivaty_data_selection = bioactivaty_data[selection]
bioactivaty_data_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
# check that the smi is fine
! cat molecule.smi | head -5
# Out:
# CC(=O)O[C@@H]1CC(=O)N1C(=O)NC(C)C	CHEMBL122071
# CCCCNC(=O)N1C(=O)C[C@H]1OC(C)=O	CHEMBL124107
# C[C@@H]1C(=O)N(C(=O)NCc2ccccc2)[C@@H]1Oc1ccc(C(=O)O)cc1	CHEMBL120853
# CC(=O)O[C@@H]1[C@@H](C)C(=O)N1C(=O)NCc1ccccc1	CHEMBL122296
# CC(=O)O[C@@H]1[C@H](C)C(=O)N1C(=O)NCc1ccccc1	CHEMBL333734

# %%
# How many molecules?
! cat molecule.smi | wc -l
# Out:
# 235

# %%
# Calculate fingerprint descriptors
# Calculate PaDEL descriptors
# Options of 1gb memory, it eliminates salts and other small organic acids, we are cleaning the chemical estructure so there is no impurity
# we want the molecular fingerprint, and it is Pubchem fingerprint
# Output descriptors into descriptors_output.csv
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
# Obtain descriptors
! bash padel.sh
# Out:
# Processing CHEMBL122071 in molecule.smi (1/235).
# Processing CHEMBL124107 in molecule.smi (2/235).
# Processing CHEMBL120853 in molecule.smi (3/235). Average speed: 1.64 s/mol.
# Processing CHEMBL122296 in molecule.smi (4/235). Average speed: 0.84 s/mol.
# Processing CHEMBL333734 in molecule.smi (5/235). Average speed: 0.74 s/mol.
# Processing CHEMBL333117 in molecule.smi (7/235). Average speed: 0.61 s/mol.
# Processing CHEMBL74483 in molecule.smi (6/235). Average speed: 0.70 s/mol.
# Processing CHEMBL334176 in molecule.smi (8/235). Average speed: 0.61 s/mol.
# Processing CHEMBL122983 in molecule.smi (9/235). Average speed: 0.59 s/mol.
# Processing CHEMBL122731 in molecule.smi (10/235). Average speed: 0.70 s/mol.
# Processing CHEMBL123589 in molecule.smi (11/235). Average speed: 0.57 s/mol.
# Processing CHEMBL331459 in molecule.smi (12/235). Average speed: 0.56 s/mol.
# Processing CHEMBL123457 in molecule.smi (13/235). Average speed: 0.52 s/mol.
# Processing CHEMBL123455 in molecule.smi (14/235). Average speed: 0.51 s/mol.
# Processing CHEMBL332366 in molecule.smi (15/235). Average speed: 0.50 s/mol.
# Processing CHEMBL331210 in molecule.smi (16/235). Average speed: 0.47 s/mol.
# Processing CHEMBL122575 in molecule.smi (17/235). Average speed: 0.46 s/mol.
# Processing CHEMBL305708 in molecule.smi (18/235). Average speed: 0.44 s/mol.
# Processing CHEMBL122963 in molecule.smi (19/235). Average speed: 0.44 s/mol.
# Processing CHEMBL49877 in molecule.smi (20/235). Average speed: 0.42 s/mol.
# Processing CHEMBL446658 in molecule.smi (21/235). Average speed: 0.40 s/mol.
# Processing CHEMBL431337 in molecule.smi (22/235). Average speed: 0.40 s/mol.
# Processing CHEMBL48421 in molecule.smi (23/235). Average speed: 0.40 s/mol.
# Processing CHEMBL47226 in molecule.smi (24/235). Average speed: 0.41 s/mol.
# Processing CHEMBL48562 in molecule.smi (25/235). Average speed: 0.40 s/mol.
# Processing CHEMBL46944 in molecule.smi (26/235). Average speed: 0.39 s/mol.
# Processing CHEMBL296301 in molecule.smi (27/235). Average speed: 0.38 s/mol.
# Processing CHEMBL49731 in molecule.smi (28/235). Average speed: 0.38 s/mol.
# Processing CHEMBL50373 in molecule.smi (30/235). Average speed: 0.37 s/mol.
# Processing CHEMBL47429 in molecule.smi (29/235). Average speed: 0.37 s/mol.
# Processing CHEMBL297341 in molecule.smi (31/235). Average speed: 0.37 s/mol.
# Processing CHEMBL298789 in molecule.smi (32/235). Average speed: 0.37 s/mol.
# Processing CHEMBL300091 in molecule.smi (33/235). Average speed: 0.37 s/mol.
# Processing CHEMBL45899 in molecule.smi (34/235). Average speed: 0.36 s/mol.
# Processing CHEMBL298170 in molecule.smi (35/235). Average speed: 0.35 s/mol.
# Processing CHEMBL295394 in molecule.smi (37/235). Average speed: 0.34 s/mol.
# Processing CHEMBL301787 in molecule.smi (36/235). Average speed: 0.35 s/mol.
# Processing CHEMBL431158 in molecule.smi (38/235). Average speed: 0.34 s/mol.
# Processing CHEMBL45799 in molecule.smi (40/235). Average speed: 0.33 s/mol.
# Processing CHEMBL49788 in molecule.smi (39/235). Average speed: 0.34 s/mol.
# Processing CHEMBL299435 in molecule.smi (41/235). Average speed: 0.33 s/mol.
# Processing CHEMBL48639 in molecule.smi (42/235). Average speed: 0.33 s/mol.
# Processing CHEMBL58311 in molecule.smi (43/235). Average speed: 0.34 s/mol.
# Processing CHEMBL421075 in molecule.smi (44/235). Average speed: 0.34 s/mol.
# Processing CHEMBL123060 in molecule.smi (45/235). Average speed: 0.33 s/mol.
# Processing CHEMBL122115 in molecule.smi (46/235). Average speed: 0.33 s/mol.
# Processing CHEMBL123391 in molecule.smi (47/235). Average speed: 0.32 s/mol.
# Processing CHEMBL333186 in molecule.smi (48/235). Average speed: 0.32 s/mol.
# Processing CHEMBL121931 in molecule.smi (49/235). Average speed: 0.32 s/mol.
# Processing CHEMBL332411 in molecule.smi (50/235). Average speed: 0.32 s/mol.
# Processing CHEMBL120448 in molecule.smi (51/235). Average speed: 0.31 s/mol.
# Processing CHEMBL124175 in molecule.smi (52/235). Average speed: 0.31 s/mol.
# Processing CHEMBL263745 in molecule.smi (53/235). Average speed: 0.31 s/mol.
# Processing CHEMBL421093 in molecule.smi (54/235). Average speed: 0.30 s/mol.
# Processing CHEMBL123109 in molecule.smi (55/235). Average speed: 0.30 s/mol.
# Processing CHEMBL122199 in molecule.smi (56/235). Average speed: 0.30 s/mol.
# Processing CHEMBL124172 in molecule.smi (57/235). Average speed: 0.30 s/mol.
# Processing CHEMBL123989 in molecule.smi (58/235). Average speed: 0.30 s/mol.
# Processing CHEMBL331182 in molecule.smi (59/235). Average speed: 0.29 s/mol.
# Processing CHEMBL333256 in molecule.smi (60/235). Average speed: 0.29 s/mol.
# Processing CHEMBL333761 in molecule.smi (61/235). Average speed: 0.29 s/mol.
# Processing CHEMBL123991 in molecule.smi (62/235). Average speed: 0.29 s/mol.
# Processing CHEMBL51623 in molecule.smi (63/235). Average speed: 0.29 s/mol.
# Processing CHEMBL298633 in molecule.smi (64/235). Average speed: 0.28 s/mol.
# Processing CHEMBL50036 in molecule.smi (65/235). Average speed: 0.28 s/mol.
# Processing CHEMBL298136 in molecule.smi (66/235). Average speed: 0.28 s/mol.
# Processing CHEMBL51822 in molecule.smi (67/235). Average speed: 0.28 s/mol.
# Processing CHEMBL300182 in molecule.smi (68/235). Average speed: 0.28 s/mol.
# Processing CHEMBL50828 in molecule.smi (69/235). Average speed: 0.28 s/mol.
# Processing CHEMBL296157 in molecule.smi (70/235). Average speed: 0.28 s/mol.
# Processing CHEMBL50073 in molecule.smi (71/235). Average speed: 0.28 s/mol.
# Processing CHEMBL417361 in molecule.smi (72/235). Average speed: 0.27 s/mol.
# Processing CHEMBL298940 in molecule.smi (73/235). Average speed: 0.27 s/mol.
# Processing CHEMBL51153 in molecule.smi (74/235). Average speed: 0.27 s/mol.
# Processing CHEMBL423120 in molecule.smi (75/235). Average speed: 0.27 s/mol.
# Processing CHEMBL300717 in molecule.smi (76/235). Average speed: 0.27 s/mol.
# Processing CHEMBL301715 in molecule.smi (77/235). Average speed: 0.27 s/mol.
# Processing CHEMBL301610 in molecule.smi (78/235). Average speed: 0.27 s/mol.
# Processing CHEMBL300679 in molecule.smi (80/235). Average speed: 0.27 s/mol.
# Processing CHEMBL301090 in molecule.smi (79/235). Average speed: 0.27 s/mol.
# Processing CHEMBL51210 in molecule.smi (81/235). Average speed: 0.27 s/mol.
# Processing CHEMBL417540 in molecule.smi (82/235). Average speed: 0.27 s/mol.
# Processing CHEMBL50970 in molecule.smi (83/235). Average speed: 0.27 s/mol.
# Processing CHEMBL50516 in molecule.smi (84/235). Average speed: 0.26 s/mol.
# Processing CHEMBL51470 in molecule.smi (85/235). Average speed: 0.27 s/mol.
# Processing CHEMBL50738 in molecule.smi (86/235). Average speed: 0.27 s/mol.
# Processing CHEMBL50745 in molecule.smi (87/235). Average speed: 0.26 s/mol.
# Processing CHEMBL298960 in molecule.smi (88/235). Average speed: 0.26 s/mol.
# Processing CHEMBL50778 in molecule.smi (89/235). Average speed: 0.26 s/mol.
# Processing CHEMBL50088 in molecule.smi (90/235). Average speed: 0.26 s/mol.
# Processing CHEMBL51006 in molecule.smi (91/235). Average speed: 0.26 s/mol.
# Processing CHEMBL2115461 in molecule.smi (92/235). Average speed: 0.26 s/mol.
# Processing CHEMBL51361 in molecule.smi (93/235). Average speed: 0.26 s/mol.
# Processing CHEMBL2115030 in molecule.smi (94/235). Average speed: 0.26 s/mol.
# Processing CHEMBL50095 in molecule.smi (95/235). Average speed: 0.26 s/mol.
# Processing CHEMBL295494 in molecule.smi (96/235). Average speed: 0.26 s/mol.
# Processing CHEMBL299204 in molecule.smi (97/235). Average speed: 0.25 s/mol.
# Processing CHEMBL298178 in molecule.smi (98/235). Average speed: 0.26 s/mol.
# Processing CHEMBL288793 in molecule.smi (99/235). Average speed: 0.26 s/mol.
# Processing CHEMBL35797 in molecule.smi (100/235). Average speed: 0.25 s/mol.
# Processing CHEMBL286322 in molecule.smi (101/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32559 in molecule.smi (102/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32486 in molecule.smi (103/235). Average speed: 0.25 s/mol.
# Processing CHEMBL263736 in molecule.smi (104/235). Average speed: 0.25 s/mol.
# Processing CHEMBL285920 in molecule.smi (105/235). Average speed: 0.25 s/mol.
# Processing CHEMBL287467 in molecule.smi (106/235). Average speed: 0.25 s/mol.
# Processing CHEMBL433040 in molecule.smi (107/235). Average speed: 0.25 s/mol.
# Processing CHEMBL36353 in molecule.smi (108/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32936 in molecule.smi (110/235). Average speed: 0.25 s/mol.
# Processing CHEMBL36010 in molecule.smi (109/235). Average speed: 0.25 s/mol.
# Processing CHEMBL35762 in molecule.smi (111/235). Average speed: 0.25 s/mol.
# Processing CHEMBL35353 in molecule.smi (112/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32918 in molecule.smi (113/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32166 in molecule.smi (114/235). Average speed: 0.25 s/mol.
# Processing CHEMBL335147 in molecule.smi (116/235). Average speed: 0.25 s/mol.
# Processing CHEMBL32171 in molecule.smi (115/235). Average speed: 0.25 s/mol.
# Processing CHEMBL57560 in molecule.smi (118/235). Average speed: 0.25 s/mol.
# Processing CHEMBL433457 in molecule.smi (117/235). Average speed: 0.25 s/mol.
# Processing CHEMBL265046 in molecule.smi (119/235). Average speed: 0.25 s/mol.
# Processing CHEMBL57561 in molecule.smi (120/235). Average speed: 0.25 s/mol.
# Processing CHEMBL52599 in molecule.smi (121/235). Average speed: 0.25 s/mol.
# Processing CHEMBL343974 in molecule.smi (122/235). Average speed: 0.25 s/mol.
# Processing CHEMBL440297 in molecule.smi (123/235). Average speed: 0.25 s/mol.
# Processing CHEMBL299063 in molecule.smi (124/235). Average speed: 0.25 s/mol.
# Processing CHEMBL56642 in molecule.smi (125/235). Average speed: 0.25 s/mol.
# Processing CHEMBL293782 in molecule.smi (126/235). Average speed: 0.25 s/mol.
# Processing CHEMBL138045 in molecule.smi (128/235). Average speed: 0.26 s/mol.
# Processing CHEMBL57617 in molecule.smi (127/235). Average speed: 0.26 s/mol.
# Processing CHEMBL59436 in molecule.smi (129/235). Average speed: 0.25 s/mol.
# Processing CHEMBL56361 in molecule.smi (130/235). Average speed: 0.25 s/mol.
# Processing CHEMBL56741 in molecule.smi (131/235). Average speed: 0.26 s/mol.
# Processing CHEMBL141311 in molecule.smi (132/235). Average speed: 0.26 s/mol.
# Processing CHEMBL345042 in molecule.smi (133/235). Average speed: 0.26 s/mol.
# Processing CHEMBL141684 in molecule.smi (135/235). Average speed: 0.26 s/mol.
# Processing CHEMBL59252 in molecule.smi (134/235). Average speed: 0.26 s/mol.
# Processing CHEMBL442168 in molecule.smi (136/235). Average speed: 0.26 s/mol.
# Processing CHEMBL55962 in molecule.smi (137/235). Average speed: 0.26 s/mol.
# Processing CHEMBL57565 in molecule.smi (138/235). Average speed: 0.26 s/mol.
# Processing CHEMBL137847 in molecule.smi (139/235). Average speed: 0.26 s/mol.
# Processing CHEMBL292678 in molecule.smi (140/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56849 in molecule.smi (141/235). Average speed: 0.26 s/mol.
# Processing CHEMBL57465 in molecule.smi (142/235). Average speed: 0.26 s/mol.
# Processing CHEMBL293998 in molecule.smi (143/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56307 in molecule.smi (145/235). Average speed: 0.26 s/mol.
# Processing CHEMBL54930 in molecule.smi (144/235). Average speed: 0.26 s/mol.
# Processing CHEMBL299043 in molecule.smi (146/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56701 in molecule.smi (147/235). Average speed: 0.26 s/mol.
# Processing CHEMBL293304 in molecule.smi (148/235). Average speed: 0.26 s/mol.
# Processing CHEMBL139405 in molecule.smi (149/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344631 in molecule.smi (150/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56153 in molecule.smi (151/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56633 in molecule.smi (152/235). Average speed: 0.26 s/mol.
# Processing CHEMBL440672 in molecule.smi (153/235). Average speed: 0.26 s/mol.
# Processing CHEMBL140485 in molecule.smi (154/235). Average speed: 0.26 s/mol.
# Processing CHEMBL293262 in molecule.smi (155/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56901 in molecule.smi (156/235). Average speed: 0.26 s/mol.
# Processing CHEMBL57169 in molecule.smi (158/235). Average speed: 0.26 s/mol.
# Processing CHEMBL141812 in molecule.smi (157/235). Average speed: 0.26 s/mol.
# Processing CHEMBL299278 in molecule.smi (160/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56210 in molecule.smi (159/235). Average speed: 0.26 s/mol.
# Processing CHEMBL299924 in molecule.smi (161/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56020 in molecule.smi (163/235). Average speed: 0.26 s/mol.
# Processing CHEMBL56516 in molecule.smi (162/235). Average speed: 0.26 s/mol.
# Processing CHEMBL55390 in molecule.smi (164/235). Average speed: 0.26 s/mol.
# Processing CHEMBL136258 in molecule.smi (165/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344166 in molecule.smi (167/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344365 in molecule.smi (166/235). Average speed: 0.26 s/mol.
# Processing CHEMBL342631 in molecule.smi (168/235). Average speed: 0.26 s/mol.
# Processing CHEMBL423909 in molecule.smi (170/235). Average speed: 0.26 s/mol.
# Processing CHEMBL341422 in molecule.smi (169/235). Average speed: 0.26 s/mol.
# Processing CHEMBL139958 in molecule.smi (171/235). Average speed: 0.26 s/mol.
# Processing CHEMBL342043 in molecule.smi (172/235). Average speed: 0.26 s/mol.
# Processing CHEMBL141639 in molecule.smi (173/235). Average speed: 0.26 s/mol.
# Processing CHEMBL341768 in molecule.smi (174/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138413 in molecule.smi (175/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138431 in molecule.smi (176/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344424 in molecule.smi (177/235). Average speed: 0.26 s/mol.
# Processing CHEMBL139395 in molecule.smi (179/235). Average speed: 0.26 s/mol.
# Processing CHEMBL140884 in molecule.smi (180/235). Average speed: 0.26 s/mol.
# Processing CHEMBL436413 in molecule.smi (178/235). Average speed: 0.26 s/mol.
# Processing CHEMBL341583 in molecule.smi (181/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138876 in molecule.smi (183/235). Average speed: 0.26 s/mol.
# Processing CHEMBL479921 in molecule.smi (182/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138762 in molecule.smi (185/235). Average speed: 0.26 s/mol.
# Processing CHEMBL343154 in molecule.smi (184/235). Average speed: 0.26 s/mol.
# Processing CHEMBL345088 in molecule.smi (186/235). Average speed: 0.27 s/mol.
# Processing CHEMBL344256 in molecule.smi (187/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138754 in molecule.smi (188/235). Average speed: 0.26 s/mol.
# Processing CHEMBL422106 in molecule.smi (190/235). Average speed: 0.26 s/mol.
# Processing CHEMBL336909 in molecule.smi (189/235). Average speed: 0.26 s/mol.
# Processing CHEMBL336230 in molecule.smi (191/235). Average speed: 0.26 s/mol.
# Processing CHEMBL342014 in molecule.smi (193/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344199 in molecule.smi (192/235). Average speed: 0.26 s/mol.
# Processing CHEMBL342871 in molecule.smi (194/235). Average speed: 0.26 s/mol.
# Processing CHEMBL139154 in molecule.smi (196/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138346 in molecule.smi (195/235). Average speed: 0.26 s/mol.
# Processing CHEMBL343989 in molecule.smi (197/235). Average speed: 0.26 s/mol.
# Processing CHEMBL337146 in molecule.smi (199/235). Average speed: 0.26 s/mol.
# Processing CHEMBL344039 in molecule.smi (198/235). Average speed: 0.26 s/mol.
# Processing CHEMBL134973 in molecule.smi (201/235). Average speed: 0.26 s/mol.
# Processing CHEMBL337312 in molecule.smi (200/235). Average speed: 0.26 s/mol.
# Processing CHEMBL138211 in molecule.smi (202/235). Average speed: 0.26 s/mol.
# Processing CHEMBL343130 in molecule.smi (203/235). Average speed: 0.27 s/mol.
# Processing CHEMBL336034 in molecule.smi (204/235). Average speed: 0.26 s/mol.
# Processing CHEMBL343116 in molecule.smi (205/235). Average speed: 0.27 s/mol.
# Processing CHEMBL138427 in molecule.smi (206/235). Average speed: 0.27 s/mol.
# Processing CHEMBL341767 in molecule.smi (207/235). Average speed: 0.27 s/mol.
# Processing CHEMBL138087 in molecule.smi (208/235). Average speed: 0.27 s/mol.
# Processing CHEMBL421758 in molecule.smi (209/235). Average speed: 0.27 s/mol.
# Processing CHEMBL344656 in molecule.smi (211/235). Average speed: 0.27 s/mol.
# Processing CHEMBL139571 in molecule.smi (210/235). Average speed: 0.27 s/mol.
# Processing CHEMBL107126 in molecule.smi (213/235). Average speed: 0.27 s/mol.
# Processing CHEMBL138141 in molecule.smi (212/235). Average speed: 0.27 s/mol.
# Processing CHEMBL442199 in molecule.smi (215/235). Average speed: 0.27 s/mol.
# Processing CHEMBL107064 in molecule.smi (214/235). Average speed: 0.27 s/mol.
# Processing CHEMBL108055 in molecule.smi (216/235). Average speed: 0.27 s/mol.
# Processing CHEMBL104823 in molecule.smi (217/235). Average speed: 0.27 s/mol.
# Processing CHEMBL323736 in molecule.smi (218/235). Average speed: 0.27 s/mol.
# Processing CHEMBL317816 in molecule.smi (219/235). Average speed: 0.27 s/mol.
# Processing CHEMBL320474 in molecule.smi (220/235). Average speed: 0.27 s/mol.
# Processing CHEMBL104680 in molecule.smi (221/235). Average speed: 0.27 s/mol.
# Processing CHEMBL317213 in molecule.smi (222/235). Average speed: 0.27 s/mol.
# Processing CHEMBL326888 in molecule.smi (223/235). Average speed: 0.27 s/mol.
# Processing CHEMBL432637 in molecule.smi (224/235). Average speed: 0.27 s/mol.
# Processing CHEMBL107078 in molecule.smi (225/235). Average speed: 0.27 s/mol.
# Processing CHEMBL106244 in molecule.smi (227/235). Average speed: 0.27 s/mol.
# Processing CHEMBL105989 in molecule.smi (226/235). Average speed: 0.27 s/mol.
# Processing CHEMBL107357 in molecule.smi (228/235). Average speed: 0.27 s/mol.
# Processing CHEMBL322676 in molecule.smi (229/235). Average speed: 0.27 s/mol.
# Processing CHEMBL104662 in molecule.smi (230/235). Average speed: 0.27 s/mol.
# Processing CHEMBL106921 in molecule.smi (231/235). Average speed: 0.27 s/mol.
# Processing CHEMBL106641 in molecule.smi (233/235). Average speed: 0.26 s/mol.
# Processing CHEMBL107963 in molecule.smi (232/235). Average speed: 0.26 s/mol.
# Processing CHEMBL108677 in molecule.smi (234/235). Average speed: 0.26 s/mol.
# Processing CHEMBL542448 in molecule.smi (235/235). Average speed: 0.26 s/mol.
# Descriptor calculation completed in 1 mins 1.462 secs . Average speed: 0.26 s/mol.

# %%
# Check
! ls -l
# Out:
# total 25660
# -rw-r--r-- 1 root root   428879 Sep  3 11:29 descriptors_output.csv
# -rw-r--r-- 1 root root    34554 Sep  3 11:30 genital_herpes_04_bioactivity_data_3class_pIC50.csv
# drwxr-xr-x 3 root root     4096 Sep  3 11:27 __MACOSX
# -rw-r--r-- 1 root root    17656 Sep  3 11:27 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor
# -rw-r--r-- 1 root root      231 Sep  3 11:26 padel.sh
# -rw-r--r-- 1 root root 25768637 Sep  3 11:26 padel.zip
# drwxr-xr-x 1 root root     4096 Sep  1 19:26 sample_data

# %%
# Preparing the X and Y Data Matrices
# X data matrix

# Lets take a look of the generated file
descriptors_output_x = pd.read_csv('descriptors_output.csv')
descriptors_output_x
# Out:
#              Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0    CHEMBL122071           1  ...             0             0
# 1    CHEMBL124107           1  ...             0             0
# 2    CHEMBL122296           1  ...             0             0
# 3    CHEMBL333734           1  ...             0             0
# 4    CHEMBL120853           1  ...             0             0
# ..            ...         ...  ...           ...           ...
# 230  CHEMBL106921           1  ...             0             0
# 231  CHEMBL106641           1  ...             0             0
# 232  CHEMBL107963           1  ...             0             0
# 233  CHEMBL542448           0  ...             0             0
# 234  CHEMBL108677           1  ...             0             0
#
# [235 rows x 882 columns]

# %%
# We only want the fingerprints, not the name
descriptors_output_x = descriptors_output_x.drop(columns=['Name'])
descriptors_output_x
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 230           1           1  ...             0             0
# 231           1           1  ...             0             0
# 232           1           1  ...             0             0
# 233           0           0  ...             0             0
# 234           1           1  ...             0             0
#
# [235 rows x 881 columns]

# %%
# Y variable
# Convert IC50 to pIC50
descriptors_output_y = bioactivaty_data['pIC50']
descriptors_output_y
# Out:
# 0      4.000000
# 1      4.167491
# 2      4.000000
# 3      5.187087
# 4      4.568636
#          ...
# 230    5.823909
# 231    5.619789
# 232    4.958607
# 233    7.214670
# 234    4.481486
# Name: pIC50, Length: 235, dtype: float64

# %%
# Merge both
descriptors = pd.concat([descriptors_output_x,descriptors_output_y], axis=1)
descriptors
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0             1           1           0  ...             0             0  4.000000
# 1             1           1           1  ...             0             0  4.167491
# 2             1           1           1  ...             0             0  4.000000
# 3             1           1           1  ...             0             0  5.187087
# 4             1           1           1  ...             0             0  4.568636
# ..          ...         ...         ...  ...           ...           ...       ...
# 230           1           1           1  ...             0             0  5.823909
# 231           1           1           0  ...             0             0  5.619789
# 232           1           1           1  ...             0             0  4.958607
# 233           0           0           0  ...             0             0  7.214670
# 234           1           1           1  ...             0             0  4.481486
#
# [235 rows x 882 columns]

# %%
# Save the data with a csv file
descriptors.to_csv('genital_herpes_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)
